# %%
# !pip install torchinfo
# !nvidia-smi
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# Wed Aug  7 11:12:27 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# import

import numpy as np
from datetime import datetime
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split, ConcatDataset
from torchvision import transforms
from torchvision import datasets
import matplotlib.pyplot as plt
import torchinfo
import os
from pytz import timezone
from tqdm import tqdm

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "0,1"

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device:', DEVICE)  # 출력결과: cuda
print('Count of using GPUs:', torch.cuda.device_count())
print('Current cuda device:', torch.cuda.current_device())
# Out:
# Device: cuda
# Count of using GPUs: 1
# Current cuda device: 0

# %%
## 하이퍼파라미터 설정
RANDOM_SEED = 4242
LEARNING_RATE = 0.01
MOMENTUM = 0.9
WEIGHT_DECAY = 5e-4
BATCH_SIZE = 128
EPOCHS = 50
IMG_SIZE = 32
NUM_CLASSES = 10

# 규제화 파라미터 설정
DROPOUT = 0.5

# %%
# 모델의 정확도를 계산하는 함수
def get_accuracy(model, data_loader, device):
    correct_predictions = 0
    total_predictions = 0
    with torch.no_grad():
        model.eval()
        for images, labels in data_loader:
            images = images.to(device)
            labels = labels.to(device)
            probabilities = F.softmax(model(images), dim=-1)
            _, predicted_labels = torch.max(probabilities, 1)

            total_predictions += labels.size(0)
            correct_predictions += (predicted_labels == labels).sum()
    return correct_predictions.float() / total_predictions

# %%
# 학습 손실과 검증 손실을 시각화
def plot_loss(train_loss, val_loss):
    plt.style.use("grayscale")
    train_loss = np.array(train_loss)
    val_loss = np.array(val_loss)
    fig, ax = plt.subplots(1, 1, figsize=(8, 4.5))
    ax.plot(train_loss, color="green", label="Training Loss")
    ax.plot(val_loss, color="red", label="Validation Loss")
    ax.set(title="Loss Over Epochs", xlabel="EPOCH", ylabel="LOSS")
    ax.legend()
    fig.show()
    plt.style.use("default")

# %%
# 모델 학습 함수
def train(train_loader, model, criterion, optimizer, device):
    model.train()
    total_loss = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)
        logits = model(images)
        loss = criterion(logits, labels)
        total_loss += loss.item() * images.size(0)
        loss.backward()
        optimizer.step()
    epoch_loss = total_loss / len(train_loader.dataset)
    return model, optimizer, epoch_loss

# %%
# 검증 데이터셋을 사용하여 모델의 성능을 평가
def validate(valid_loader, model, criterion, device):
    model.eval()
    total_loss = 0

    for images, labels in valid_loader:
        images = images.to(device)
        labels = labels.to(device)

        # 순전파와 손실 기록하기
        logits = model(images)
        loss = criterion(logits, labels)
        total_loss += loss.item() * images.size(0)

    epoch_loss = total_loss / len(valid_loader.dataset)
    return model, epoch_loss

# %%
def training_loop(
    model,
    criterion,
    optimizer,
    lr_scheduler,
    train_loader,
    valid_loader,
    epochs,
    device,
    print_every=1,
):
    train_losses = []
    valid_losses = []
    print(
        datetime.now(timezone("Asia/Seoul")).time().replace(microsecond=0),
        "--- Start Training Loop ---",
    )

    for epoch in range(epochs):
        # training
        model.train()
        running_loss = 0.0
        train_loader_tqdm = tqdm(
            train_loader, desc=f"Epoch {epoch + 1}/{epochs}", leave=False
        )
        for inputs, labels in train_loader_tqdm:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)

        train_loss = running_loss / len(train_loader.dataset)
        train_losses.append(train_loss)

        # validation
        model.eval()
        running_loss = 0.0
        valid_loader_tqdm = tqdm(
            valid_loader, desc=f"Validation {epoch + 1}/{epochs}", leave=False
        )
        with torch.no_grad():
            for inputs, labels in valid_loader_tqdm:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                running_loss += loss.item() * inputs.size(0)

        valid_loss = running_loss / len(valid_loader.dataset)
        valid_losses.append(valid_loss)

        if epoch % print_every == (print_every - 1):

            train_acc = get_accuracy(model, train_loader, device=device)
            valid_acc = get_accuracy(model, valid_loader, device=device)

            print(
                datetime.now(timezone("Asia/Seoul")).time().replace(microsecond=0),
                "--- ",
                f"Epoch: {epoch + 1}\t"
                f"Train loss: {train_loss:.4f}\t"
                f"Valid loss: {valid_loss:.4f}\t"
                f"Train accuracy: {100 * train_acc:.2f}\t"
                f"Valid accuracy: {100 * valid_acc:.2f}",
            )

        lr_scheduler.step(valid_acc)

    plot_loss(train_losses, valid_losses)

    return model, optimizer, (train_losses, valid_losses)

# %%
# VGGNet16 모델의 Block 정의
class VGGNet16Block(nn.Module):
    def __init__(self, in_channels, out_channels, num_convs):
        super(VGGNet16Block, self).__init__()
        self.convs = nn.ModuleList(
            [
                nn.Conv2d(
                    in_channels if i == 0 else out_channels,
                    out_channels,
                    kernel_size=3,
                    padding=1,
                )
                for i in range(num_convs)
            ]
        )
        self.batchnorm = nn.BatchNorm2d(out_channels)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        for conv in self.convs:
            x = F.relu(conv(x))
        x = self.batchnorm(x)
        x = self.pool(x)
        return x


# VGGNet16 모델 정의
class MiniVGGNet16(nn.Module):
    def __init__(self):
        super(MiniVGGNet16, self).__init__()
        self.dropout = nn.Dropout(DROPOUT)

        self.block1 = VGGNet16Block(3, 64, num_convs=2)
        self.block2 = VGGNet16Block(64, 128, num_convs=2)
        self.block3 = VGGNet16Block(128, 256, num_convs=3)
        self.block4 = VGGNet16Block(256, 512, num_convs=3)
        self.block5 = VGGNet16Block(512, 512, num_convs=3)

        self.fc14 = nn.Linear(512, 1024)
        self.fc15 = nn.Linear(1024, 1024)
        self.fc16 = nn.Linear(1024, NUM_CLASSES)

    def forward(self, x):
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)

        x = x.view(-1, 512)
        x = F.relu(self.fc14(x))
        x = self.dropout(x)
        x = F.relu(self.fc15(x))
        x = self.dropout(x)
        logits = self.fc16(x)

        return logits


torchinfo.summary(
    MiniVGGNet16(),
    input_size=(1, 3, IMG_SIZE, IMG_SIZE),
    col_names=["input_size", "output_size", "num_params", "kernel_size"],
    row_settings=["depth", "var_names"],
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name):depth-idx)        Input Shape               Output Shape              Param #                   Kernel Shape
# ============================================================================================================================================
# MiniVGGNet16 (MiniVGGNet16)              [1, 3, 32, 32]            [1, 10]                   --                        --
# ├─VGGNet16Block (block1): 1-1            [1, 3, 32, 32]            [1, 64, 16, 16]           --                        --
# │    └─ModuleList (convs): 2-1           --                        --                        --                        --
# │    │    └─Conv2d (0): 3-1              [1, 3, 32, 32]            [1, 64, 32, 32]           1,792                     [3, 3]
# │    │    └─Conv2d (1): 3-2              [1, 64, 32, 32]           [1, 64, 32, 32]           36,928                    [3, 3]
# │    └─BatchNorm2d (batchnorm): 2-2      [1, 64, 32, 32]           [1, 64, 32, 32]           128                       --
# │    └─MaxPool2d (pool): 2-3             [1, 64, 32, 32]           [1, 64, 16, 16]           --                        2
# ├─VGGNet16Block (block2): 1-2            [1, 64, 16, 16]           [1, 128, 8, 8]            --                        --
# │    └─ModuleList (convs): 2-4           --                        --                        --                        --
# │    │    └─Conv2d (0): 3-3              [1, 64, 16, 16]           [1, 128, 16, 16]          73,856                    [3, 3]
# │    │    └─Conv2d (1): 3-4              [1, 128, 16, 16]          [1, 128, 16, 16]          147,584                   [3, 3]
# │    └─BatchNorm2d (batchnorm): 2-5      [1, 128, 16, 16]          [1, 128, 16, 16]          256                       --
# │    └─MaxPool2d (pool): 2-6             [1, 128, 16, 16]          [1, 128, 8, 8]            --                        2
# ├─VGGNet16Block (block3): 1-3            [1, 128, 8, 8]            [1, 256, 4, 4]            --                        --
# │    └─ModuleList (convs): 2-7           --                        --                        --                        --
# │    │    └─Conv2d (0): 3-5              [1, 128, 8, 8]            [1, 256, 8, 8]            295,168                   [3, 3]
# │    │    └─Conv2d (1): 3-6              [1, 256, 8, 8]            [1, 256, 8, 8]            590,080                   [3, 3]
# │    │    └─Conv2d (2): 3-7              [1, 256, 8, 8]            [1, 256, 8, 8]            590,080                   [3, 3]
# │    └─BatchNorm2d (batchnorm): 2-8      [1, 256, 8, 8]            [1, 256, 8, 8]            512                       --
# │    └─MaxPool2d (pool): 2-9             [1, 256, 8, 8]            [1, 256, 4, 4]            --                        2
# ├─VGGNet16Block (block4): 1-4            [1, 256, 4, 4]            [1, 512, 2, 2]            --                        --
# │    └─ModuleList (convs): 2-10          --                        --                        --                        --
# │    │    └─Conv2d (0): 3-8              [1, 256, 4, 4]            [1, 512, 4, 4]            1,180,160                 [3, 3]
# │    │    └─Conv2d (1): 3-9              [1, 512, 4, 4]            [1, 512, 4, 4]            2,359,808                 [3, 3]
# │    │    └─Conv2d (2): 3-10             [1, 512, 4, 4]            [1, 512, 4, 4]            2,359,808                 [3, 3]
# │    └─BatchNorm2d (batchnorm): 2-11     [1, 512, 4, 4]            [1, 512, 4, 4]            1,024                     --
# │    └─MaxPool2d (pool): 2-12            [1, 512, 4, 4]            [1, 512, 2, 2]            --                        2
# ├─VGGNet16Block (block5): 1-5            [1, 512, 2, 2]            [1, 512, 1, 1]            --                        --
# │    └─ModuleList (convs): 2-13          --                        --                        --                        --
# │    │    └─Conv2d (0): 3-11             [1, 512, 2, 2]            [1, 512, 2, 2]            2,359,808                 [3, 3]
# │    │    └─Conv2d (1): 3-12             [1, 512, 2, 2]            [1, 512, 2, 2]            2,359,808                 [3, 3]
# │    │    └─Conv2d (2): 3-13             [1, 512, 2, 2]            [1, 512, 2, 2]            2,359,808                 [3, 3]
# │    └─BatchNorm2d (batchnorm): 2-14     [1, 512, 2, 2]            [1, 512, 2, 2]            1,024                     --
# │    └─MaxPool2d (pool): 2-15            [1, 512, 2, 2]            [1, 512, 1, 1]            --                        2
# ├─Linear (fc14): 1-6                     [1, 512]                  [1, 1024]                 525,312                   --
# ├─Dropout (dropout): 1-7                 [1, 1024]                 [1, 1024]                 --                        --
# ├─Linear (fc15): 1-8                     [1, 1024]                 [1, 1024]                 1,049,600                 --
# ├─Dropout (dropout): 1-9                 [1, 1024]                 [1, 1024]                 --                        --
# ├─Linear (fc16): 1-10                    [1, 1024]                 [1, 10]                   10,250                    --
# ============================================================================================================================================
# Total params: 16,302,794
# Trainable params: 16,302,794
# Non-trainable params: 0
# Total mult-adds (M): 315.06
# ============================================================================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.23
# Params size (MB): 65.21
# Estimated Total Size (MB): 68.45
# ============================================================================================================================================

# %%
transform = transforms.Compose(
    [
        transforms.Resize((IMG_SIZE, IMG_SIZE)),
        transforms.RandomHorizontalFlip(),  # 50% 확률로 수평 뒤집기
        transforms.ToTensor(),
    ]
)

# 데이터셋 다운로드 및 생성
full_dataset = datasets.CIFAR10(root="cifar10_data", train=True, transform=transform, download=True)
test_dataset = datasets.CIFAR10(root="cifar10_data", train=False, transform=transform)

test_size = len(test_dataset)
valid_size = test_size
train_size = len(full_dataset) - valid_size

train_dataset, valid_dataset = random_split(full_dataset, [train_size, valid_size])

# 데이터 로더 정의
train_loader = DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
valid_loader = DataLoader(dataset=valid_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)
test_loader = DataLoader(dataset=test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=4)

# 불러온 CIFAR-10 데이터 확인
ROW_IMG = 10
N_ROWS = 5

fig = plt.figure(figsize=(15, 8))
for index in range(1, ROW_IMG * N_ROWS + 1):
    plt.subplot(N_ROWS, ROW_IMG, index)
    plt.axis("off")
    img = train_dataset.dataset[index][0]
    img = img.permute(1, 2, 0)  # (채널, 높이, 너비) -> (높이, 너비, 채널)
    plt.imshow(img)

fig.suptitle("CIFAR-10 Dataset")
plt.show()

# 데이터셋 크기 출력
print("train dataset size: ", len(train_dataset))
print("valid dataset size: ", len(valid_dataset))
print("test dataset size: ", len(test_dataset))
# Out:
# Files already downloaded and verified
# train dataset size:  40000
# valid dataset size:  10000
# test dataset size:  10000

# %%
torch.manual_seed(RANDOM_SEED)

_model = MiniVGGNet16().cuda()
model = nn.DataParallel(_model).to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY, nesterov=True)
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.1, patience=3, verbose=True)

criterion = nn.CrossEntropyLoss()

model, optimizer, _ = training_loop(
    model, criterion, optimizer, lr_scheduler, train_loader, valid_loader, EPOCHS, DEVICE
)
# Out:
# 20:40:16 --- Start Training Loop ---
# 20:40:49 ---  Epoch: 1	Train loss: 1.6266	Valid loss: 1.2749	Train accuracy: 54.32	Valid accuracy: 54.34
# 20:41:22 ---  Epoch: 2	Train loss: 1.0905	Valid loss: 1.4235	Train accuracy: 52.16	Valid accuracy: 52.17
# 20:41:55 ---  Epoch: 3	Train loss: 0.8651	Valid loss: 0.9408	Train accuracy: 69.38	Valid accuracy: 67.73
# 20:42:29 ---  Epoch: 4	Train loss: 0.7269	Valid loss: 0.7562	Train accuracy: 77.02	Valid accuracy: 74.39
# 20:43:02 ---  Epoch: 5	Train loss: 0.6294	Valid loss: 0.7215	Train accuracy: 78.40	Valid accuracy: 75.13
# 20:43:35 ---  Epoch: 6	Train loss: 0.5599	Valid loss: 0.6795	Train accuracy: 81.25	Valid accuracy: 77.50
# 20:44:08 ---  Epoch: 7	Train loss: 0.4965	Valid loss: 0.6053	Train accuracy: 84.51	Valid accuracy: 79.56
# 20:44:41 ---  Epoch: 8	Train loss: 0.4312	Valid loss: 0.6086	Train accuracy: 85.50	Valid accuracy: 79.35
# 20:45:14 ---  Epoch: 9	Train loss: 0.3922	Valid loss: 0.5771	Train accuracy: 86.99	Valid accuracy: 80.59
# 20:45:50 ---  Epoch: 10	Train loss: 0.3435	Valid loss: 0.6004	Train accuracy: 88.10	Valid accuracy: 80.85
# 20:46:23 ---  Epoch: 11	Train loss: 0.3150	Valid loss: 0.5853	Train accuracy: 88.98	Valid accuracy: 81.50
# 20:46:56 ---  Epoch: 12	Train loss: 0.2845	Valid loss: 0.5369	Train accuracy: 91.99	Valid accuracy: 82.97
# 20:47:29 ---  Epoch: 13	Train loss: 0.2528	Valid loss: 0.5954	Train accuracy: 90.74	Valid accuracy: 81.28
# 20:48:02 ---  Epoch: 14	Train loss: 0.2310	Valid loss: 0.5563	Train accuracy: 92.74	Valid accuracy: 83.07
# 20:48:35 ---  Epoch: 15	Train loss: 0.2115	Valid loss: 0.6280	Train accuracy: 90.49	Valid accuracy: 80.85
# 20:49:09 ---  Epoch: 16	Train loss: 0.1909	Valid loss: 0.6377	Train accuracy: 91.44	Valid accuracy: 81.95
# 20:49:42 ---  Epoch: 17	Train loss: 0.1732	Valid loss: 0.6034	Train accuracy: 93.90	Valid accuracy: 83.36
# 20:50:15 ---  Epoch: 18	Train loss: 0.1606	Valid loss: 0.5439	Train accuracy: 95.14	Valid accuracy: 83.88
# 20:50:48 ---  Epoch: 19	Train loss: 0.1531	Valid loss: 0.7590	Train accuracy: 90.43	Valid accuracy: 81.16
# 20:51:21 ---  Epoch: 20	Train loss: 0.1444	Valid loss: 0.5864	Train accuracy: 94.62	Valid accuracy: 83.66
# 20:51:54 ---  Epoch: 21	Train loss: 0.1263	Valid loss: 0.6186	Train accuracy: 95.63	Valid accuracy: 83.46
# 20:52:27 ---  Epoch: 22	Train loss: 0.1246	Valid loss: 0.6585	Train accuracy: 94.56	Valid accuracy: 83.15
# 20:53:00 ---  Epoch: 23	Train loss: 0.0594	Valid loss: 0.4863	Train accuracy: 99.24	Valid accuracy: 87.02
# 20:53:33 ---  Epoch: 24	Train loss: 0.0331	Valid loss: 0.4998	Train accuracy: 99.55	Valid accuracy: 87.51
# 20:54:06 ---  Epoch: 25	Train loss: 0.0232	Valid loss: 0.5246	Train accuracy: 99.75	Valid accuracy: 87.41
# 20:54:40 ---  Epoch: 26	Train loss: 0.0157	Valid loss: 0.5551	Train accuracy: 99.85	Valid accuracy: 87.44
# 20:55:13 ---  Epoch: 27	Train loss: 0.0113	Valid loss: 0.5611	Train accuracy: 99.88	Valid accuracy: 87.62
# 20:55:46 ---  Epoch: 28	Train loss: 0.0086	Valid loss: 0.5834	Train accuracy: 99.93	Valid accuracy: 87.58
# 20:56:19 ---  Epoch: 29	Train loss: 0.0075	Valid loss: 0.5873	Train accuracy: 99.94	Valid accuracy: 87.97
# 20:56:52 ---  Epoch: 30	Train loss: 0.0055	Valid loss: 0.6007	Train accuracy: 99.97	Valid accuracy: 87.40
# 20:57:25 ---  Epoch: 31	Train loss: 0.0042	Valid loss: 0.6229	Train accuracy: 99.96	Valid accuracy: 87.49
# 20:57:58 ---  Epoch: 32	Train loss: 0.0045	Valid loss: 0.6288	Train accuracy: 99.97	Valid accuracy: 87.54
# 20:58:31 ---  Epoch: 33	Train loss: 0.0033	Valid loss: 0.6387	Train accuracy: 99.98	Valid accuracy: 87.54
# 20:59:04 ---  Epoch: 34	Train loss: 0.0026	Valid loss: 0.6429	Train accuracy: 99.97	Valid accuracy: 87.73
# 20:59:37 ---  Epoch: 35	Train loss: 0.0025	Valid loss: 0.6331	Train accuracy: 99.98	Valid accuracy: 87.98
# 21:00:10 ---  Epoch: 36	Train loss: 0.0031	Valid loss: 0.6424	Train accuracy: 99.98	Valid accuracy: 87.66
# 21:00:43 ---  Epoch: 37	Train loss: 0.0027	Valid loss: 0.6243	Train accuracy: 99.98	Valid accuracy: 87.88
# 21:01:17 ---  Epoch: 38	Train loss: 0.0023	Valid loss: 0.6510	Train accuracy: 99.98	Valid accuracy: 88.00
# 21:01:50 ---  Epoch: 39	Train loss: 0.0022	Valid loss: 0.6539	Train accuracy: 99.98	Valid accuracy: 87.68
# 21:02:24 ---  Epoch: 40	Train loss: 0.0024	Valid loss: 0.6597	Train accuracy: 99.99	Valid accuracy: 87.85
# 21:02:57 ---  Epoch: 41	Train loss: 0.0027	Valid loss: 0.6436	Train accuracy: 99.98	Valid accuracy: 87.91
# 21:03:31 ---  Epoch: 42	Train loss: 0.0021	Valid loss: 0.6384	Train accuracy: 99.98	Valid accuracy: 87.80
# 21:04:04 ---  Epoch: 43	Train loss: 0.0022	Valid loss: 0.6478	Train accuracy: 99.98	Valid accuracy: 88.01
# 21:04:37 ---  Epoch: 44	Train loss: 0.0026	Valid loss: 0.6390	Train accuracy: 99.99	Valid accuracy: 87.35
# 21:05:11 ---  Epoch: 45	Train loss: 0.0025	Valid loss: 0.6259	Train accuracy: 99.99	Valid accuracy: 87.66
# 21:05:44 ---  Epoch: 46	Train loss: 0.0026	Valid loss: 0.6538	Train accuracy: 99.98	Valid accuracy: 87.78
# 21:06:18 ---  Epoch: 47	Train loss: 0.0024	Valid loss: 0.6404	Train accuracy: 99.99	Valid accuracy: 87.84
# 21:06:50 ---  Epoch: 48	Train loss: 0.0024	Valid loss: 0.6450	Train accuracy: 99.99	Valid accuracy: 87.68
# 21:07:24 ---  Epoch: 49	Train loss: 0.0026	Valid loss: 0.6458	Train accuracy: 99.98	Valid accuracy: 87.87
# 21:07:57 ---  Epoch: 50	Train loss: 0.0024	Valid loss: 0.6674	Train accuracy: 99.97	Valid accuracy: 88.04

# %%
import matplotlib.pyplot as plt

# 테스트 데이터셋을 사용하여 모델의 성능을 평가하고 틀린 예시를 저장
def test_and_collect_mistakes(test_loader, model, criterion, device):
    model.eval()  # 평가 모드로 전환
    total_loss = 0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    mistakes = []

    with torch.no_grad():  # 평가시에는 그래디언트 계산 불필요
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            # 순전파와 손실 기록하기
            logits = model(images)
            loss = criterion(logits, labels)
            total_loss += loss.item() * images.size(0)

            # 예측 및 정확도 계산
            _, preds = torch.max(logits, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # 틀린 예시 저장
            for i in range(len(labels)):
                if preds[i] != labels[i]:
                    mistakes.append((images[i].cpu(), labels[i].cpu(), preds[i].cpu()))

    epoch_loss = total_loss / len(test_loader.dataset)
    accuracy = correct / total

    print(f"Test Loss: {epoch_loss:.4f}, Test Accuracy: {accuracy:.4f}")
    return epoch_loss, accuracy, all_preds, all_labels, mistakes

# 모델 학습이 완료된 후 평가 수행
test_loss, test_accuracy, test_preds, test_labels, mistakes = test_and_collect_mistakes(test_loader, model, criterion, DEVICE)

# 틀린 예시 시각화
def plot_mistakes(mistakes, num_examples=20):
    plt.figure(figsize=(8, 8))
    for i, (image, true_label, pred_label) in enumerate(mistakes[:num_examples]):
        plt.subplot(5, 4, i + 1)
        plt.axis('off')
        image = image.permute(1, 2, 0)
        plt.imshow(image)
        plt.title(f'True: {true_label}, Pred: {pred_label}')
    plt.show()

# 틀린 예시 출력
plot_mistakes(mistakes)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Test Loss: 0.6626, Test Accuracy: 0.8723
